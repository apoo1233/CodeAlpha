# %%
import pandas as pd

data = {
    "Student_ID": range(1, 21),
    "Gender": [
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male"
    ],
    "Age": [
        18, 19, 18, 20, 18,
        19, 18, 20, 19, 18,
        20, 19, 18, 20, 19,
        18, 20, 19, 18, 20
    ],
    "Study_Hours": [
        4, 2, 5, 3, 6,
        2, 7, 4, 5, 3,
        6, 2, 8, 3, 5,
        4, 7, 2, 6, 3
    ],
    "Attendance": [
        85, 70, 92, 75, 95,
        68, 90, 82, 88, 72,
        94, 65, 98, 78, 91,
        84, 96, 69, 93, 76
    ],
    "Math": [
        78, 65, 88, 70, 92,
        60, 85, 76, 90, 68,
        87, 58, 95, 72, 84,
        79, 91, 63, 89, 74
    ],
    "Science": [
        82, 68, 90, 72, 94,
        62, 88, 79, 91, 70,
        89, 61, 97, 75, 86,
        81, 93, 65, 92, 77
    ],
    "English": [
        75, 60, 86, 68, 90,
        58, 84, 74, 88, 65,
        85, 56, 94, 70, 82,
        77, 89, 61, 87, 72
    ]
}

df = pd.DataFrame(data)

print("Dataset created successfully!")
# Out:
# Dataset created successfully!

# %%
df
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English
# 0            1  Female   18            4          85    78       82       75
# 1            2    Male   19            2          70    65       68       60
# 2            3  Female   18            5          92    88       90       86
# 3            4    Male   20            3          75    70       72       68
# 4            5  Female   18            6          95    92       94       90
# 5            6    Male   19            2          68    60       62       58
# 6            7  Female   18            7          90    85       88       84
# 7            8    Male   20            4          82    76       79       74
# 8            9  Female   19            5          88    90       91       88
# 9           10    Male   18            3          72    68       70       65
# 10          11  Female   20            6          94    87       89       85
# ...

# %%
df.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English
# 0           1  Female   18            4          85    78       82       75
# 1           2    Male   19            2          70    65       68       60
# 2           3  Female   18            5          92    88       90       86
# 3           4    Male   20            3          75    70       72       68
# 4           5  Female   18            6          95    92       94       90

# %%
df.tail()
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English
# 15          16    Male   18            4          84    79       81       77
# 16          17  Female   20            7          96    91       93       89
# 17          18    Male   19            2          69    63       65       61
# 18          19  Female   18            6          93    89       92       87
# 19          20    Male   20            3          76    74       77       72

# %%
df.shape
# Out:
# (20, 8)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Study_Hours', 'Attendance', 'Math',
#        'Science', 'English'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID      int64
# Gender         object
# Age             int64
# Study_Hours     int64
# Attendance      int64
# Math            int64
# Science         int64
# English         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student_ID   20 non-null     int64
#  1   Gender       20 non-null     object
#  2   Age          20 non-null     int64
#  3   Study_Hours  20 non-null     int64
#  4   Attendance   20 non-null     int64
#  5   Math         20 non-null     int64
#  6   Science      20 non-null     int64
#  7   English      20 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance       Math    Science  \
# count    20.00000  20.000000    20.000000   20.000000  20.000000  20.000000
# mean     10.50000  18.900000     4.350000   83.050000  78.200000  80.600000
# std       5.91608   0.852242     1.871532   10.654749  11.523888  11.357353
# min       1.00000  18.000000     2.000000   65.000000  58.000000  61.000000
# 25%       5.75000  18.000000     3.000000   74.250000  69.500000  71.500000
# 50%      10.50000  19.000000     4.000000   84.500000  78.500000  81.500000
# 75%      15.25000  20.000000     6.000000   92.250000  88.250000  90.250000
# max      20.00000  20.000000     8.000000   98.000000  95.000000  97.000000
#
#          English
# count  20.000000
# mean   76.050000
# std    11.883093
# min    56.000000
# 25%    67.250000
# 50%    76.000000
# 75%    86.250000
# max    94.000000

# %%
df.isnull().sum()
# Out:
# Student_ID     0
# Gender         0
# Age            0
# Study_Hours    0
# Attendance     0
# Math           0
# Science        0
# English        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Average Math Marks:", df["Math"].mean())
print("Average Science Marks:", df["Science"].mean())
print("Average English Marks:", df["English"].mean())
# Out:
# Average Math Marks: 78.2
# Average Science Marks: 80.6
# Average English Marks: 76.05

# %%
print("Highest Math Mark:", df["Math"].max())
print("Highest Science Mark:", df["Science"].max())
print("Highest English Mark:", df["English"].max())
# Out:
# Highest Math Mark: 95
# Highest Science Mark: 97
# Highest English Mark: 94

# %%
print("Lowest Math Mark:", df["Math"].min())
print("Lowest Science Mark:", df["Science"].min())
print("Lowest English Mark:", df["English"].min())
# Out:
# Lowest Math Mark: 58
# Lowest Science Mark: 61
# Lowest English Mark: 56

# %%
df["Average_Marks"] = df[["Math", "Science", "English"]].mean(axis=1)

df.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 0           1  Female   18            4          85    78       82       75
# 1           2    Male   19            2          70    65       68       60
# 2           3  Female   18            5          92    88       90       86
# 3           4    Male   20            3          75    70       72       68
# 4           5  Female   18            6          95    92       94       90
#
#    Average_Marks
# 0      78.333333
# 1      64.333333
# 2      88.000000
# 3      70.000000
# 4      92.000000

# %%
df["Average_Marks"] = df[["Math", "Science", "English"]].mean(axis=1)

df.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 0           1  Female   18            4          85    78       82       75
# 1           2    Male   19            2          70    65       68       60
# 2           3  Female   18            5          92    88       90       86
# 3           4    Male   20            3          75    70       72       68
# 4           5  Female   18            6          95    92       94       90
#
#    Average_Marks
# 0      78.333333
# 1      64.333333
# 2      88.000000
# 3      70.000000
# 4      92.000000

# %%
df.sort_values("Average_Marks", ascending=False).head(5)
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 12          13  Female   18            8          98    95       97       94
# 4            5  Female   18            6          95    92       94       90
# 16          17  Female   20            7          96    91       93       89
# 8            9  Female   19            5          88    90       91       88
# 18          19  Female   18            6          93    89       92       87
#
#     Average_Marks
# 12      95.333333
# 4       92.000000
# 16      91.000000
# 8       89.666667
# 18      89.333333

# %%
df.sort_values("Average_Marks", ascending=False).head(5)
# Out:
#     Student_ID  Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 12          13  Female   18            8          98    95       97       94
# 4            5  Female   18            6          95    92       94       90
# 16          17  Female   20            7          96    91       93       89
# 8            9  Female   19            5          88    90       91       88
# 18          19  Female   18            6          93    89       92       87
#
#     Average_Marks
# 12      95.333333
# 4       92.000000
# 16      91.000000
# 8       89.666667
# 18      89.333333

# %%
df[["Study_Hours", "Average_Marks"]].corr()
# Out:
#                Study_Hours  Average_Marks
# Study_Hours       1.000000       0.937609
# Average_Marks     0.937609       1.000000

# %%
df.sort_values("Average_Marks").head(5)
# Out:
#     Student_ID Gender  Age  Study_Hours  Attendance  Math  Science  English  \
# 11          12   Male   19            2          65    58       61       56
# 5            6   Male   19            2          68    60       62       58
# 17          18   Male   19            2          69    63       65       61
# 1            2   Male   19            2          70    65       68       60
# 9           10   Male   18            3          72    68       70       65
#
#     Average_Marks
# 11      58.333333
# 5       60.000000
# 17      63.000000
# 1       64.333333
# 9       67.666667

# %%
df[["Attendance", "Average_Marks"]].corr()
# Out:
#                Attendance  Average_Marks
# Attendance       1.000000       0.983729
# Average_Marks    0.983729       1.000000

# %%
df.groupby("Gender")["Average_Marks"].mean()
# Out:
# Gender
# Female    88.033333
# Male      68.533333
# Name: Average_Marks, dtype: float64

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance       Math    Science  \
# count    20.00000  20.000000    20.000000   20.000000  20.000000  20.000000
# mean     10.50000  18.900000     4.350000   83.050000  78.200000  80.600000
# std       5.91608   0.852242     1.871532   10.654749  11.523888  11.357353
# min       1.00000  18.000000     2.000000   65.000000  58.000000  61.000000
# 25%       5.75000  18.000000     3.000000   74.250000  69.500000  71.500000
# 50%      10.50000  19.000000     4.000000   84.500000  78.500000  81.500000
# 75%      15.25000  20.000000     6.000000   92.250000  88.250000  90.250000
# max      20.00000  20.000000     8.000000   98.000000  95.000000  97.000000
#
#          English  Average_Marks
# count  20.000000      20.000000
# mean   76.050000      78.283333
# std    11.883093      11.577996
# min    56.000000      58.333333
# 25%    67.250000      69.416667
# 50%    76.000000      78.666667
# 75%    86.250000      88.333333
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                Student_ID       Age  Study_Hours  Attendance      Math  \
# Student_ID       1.000000  0.219214     0.111708    0.076399  0.088779
# Age              0.219214  1.000000    -0.273883   -0.242859 -0.255089
# Study_Hours      0.111708 -0.273883     1.000000    0.946622  0.933674
# Attendance       0.076399 -0.242859     0.946622    1.000000  0.982383
# Math             0.088779 -0.255089     0.933674    0.982383  1.000000
# Science          0.083031 -0.259917     0.935479    0.984436  0.998337
# English          0.111924 -0.248937     0.941067    0.981848  0.998059
# Average_Marks    0.094896 -0.254786     0.937609    0.983729  0.999666
#
#                 Science   English  Average_Marks
# Student_ID     0.083031  0.111924       0.094896
# Age           -0.259917 -0.248937      -0.254786
# Study_Hours    0.935479  0.941067       0.937609
# Attendance     0.984436  0.981848       0.983729
# Math           0.998337  0.998059       0.999666
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,5))

plt.scatter(df["Study_Hours"], df["Average_Marks"])

plt.xlabel("Study Hours")
plt.ylabel("Average Marks")
plt.title("Study Hours vs Average Marks")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Attendance"], df["Average_Marks"])

plt.xlabel("Attendance (%)")
plt.ylabel("Average Marks")
plt.title("Attendance vs Average Marks")

plt.show()

# %%
subject_average = df[["Math", "Science", "English"]].mean()

print(subject_average)
# Out:
# Math       78.20
# Science    80.60
# English    76.05
# dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df[["Math", "Science", "English"]])

plt.title("Subject Marks Distribution")

plt.show()
